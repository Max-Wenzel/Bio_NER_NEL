# %%
from seqlearn.datasets import load_conll
from seqlearn.perceptron import StructuredPerceptron
from seqlearn.evaluation import bio_f_score
from seqlearn.hmm import MultinomialHMM
from nltk.stem import PorterStemmer
import numpy as np
import pandas as pd
import sklearn as sk
import nltk as nl
import os
import re
import sys
import unidecode
from glob import glob

# %%
train_path = "../Data/bio-ner/train"
s_b = '_S_B_'
test_path = "../Data/bio-ner/dev"
train_files = glob(train_path + "/*.tsv")
ps = PorterStemmer()

# %%
def proc_text(word):
    word = word.lower()
    return unidecode.unidecode(ps.stem(word))

# %%
def create_file(pname, tname, step_one=False):
    file_data = []
    for file_name in pname:
        file = []
        with open(file_name, encoding='utf-8') as f:

            for line in f:
                par_line = line[:-1].split('\t')
                if par_line[0] != '-DOCSTART-':
                    if len(par_line) == 1:
                        file.append([s_b, 'O'])
                    else:
                        file.append([proc_text(par_line[0]), par_line[3]])
        file_data.append((file, file_name))
    data_pos = [[s_b, s_b, 'O']]
    
    for f in file_data:
        sentence = []
        for word in f[0][1:]:
            if word[0] == s_b:
                pos = nl.pos_tag([w[0] for w in sentence])
                for ii in range(len(sentence)):
                    sentence[ii][1] = pos[ii][1]
                data_pos += (sentence + [[s_b, s_b, 'O']])
                sentence = []
            else:
                sentence.append([word[0], '', word[1]])

    if os.path.exists(tname): # replace files instead of adding on 
        os.remove(tname)

    with open(tname, 'a') as f:
        for line in data_pos:
            if step_one:
                f.write("{}\t{}\t{}\n".format(line[0], line[1], line[2][0]))
            else:
                f.write("{}\t{}\t{}\n".format(line[0], line[1], line[2]))
    return data_pos

# %%
def features(seq, i): # The Feature Extractor! aka 90% of this project
	p = seq[i].split()[0]
	pos = seq[i].split()[1]
	yield "word=" + p # Current word and POS
	yield "pos=" + pos
	if i == 0: # add info for the previous word
		yield "preword=" + "START"
		yield "prepos=" + "START"
	else:
		pp = seq[i-1].split()[0]
		ppos = seq[i-1].split()[1]
		yield "prepos=" + ppos
		if pp.isupper() and len(pp) == 3: # check if previous word is acronym 
			yield "preUpper"
		if re.search(r"\d", pp.lower()): # check if prev word has number
			yield "preNumber"
		yield "preword=" + pp.lower()
	if (i + 1) == len(seq):
		yield "folword=" + "END"
		yield "folpos=" + "END"
	else: # check the same for the next word
		nnp = seq[i+1].split()[0]
		nnpos = seq[i+1].split()[1]
		yield "folpos=" + nnpos
		if nnp.isupper():
			yield "folUpper"
		if re.search(r"\d", nnp.lower()):
			yield "folNumber"
		yield "folword=" + nnp.lower()
	if p.isupper() and len(p) == 3:
		yield "Uppercase"
	if re.search(r"\d", p.lower()):
		yield "Number"
	if len(p) > 8: # check if current word is unusually long 
		yield "Long"

# %%
b = create_file(glob(train_path + "/*.tsv"), "train")

# %%
X_train, y_train, l_train = load_conll("train", features)

# %%
a = create_file(glob(test_path + "/*.tsv") ,"test")

# %%
X_test, y_test, l_test = load_conll("test", features)

# %%
per = StructuredPerceptron(lr_exponent=0.35,max_iter=300,verbose=1) # Some trial and error found that

per.fit(X_train, y_train, l_train)  # fit and predict
y_p = per.predict(X_test, l_test)
# Out:
# Iteration  1... loss = 0.6970
# Iteration  2... loss = 0.3848
# Iteration  3... loss = 0.3763
# Iteration  4... loss = 0.2763
# Iteration  5... loss = 0.3843
# Iteration  6... loss = 0.3574
# Iteration  7... loss = 0.2784
# Iteration  8... loss = 0.2437
# Iteration  9... loss = 0.2415
# Iteration 10... loss = 0.2571
# Iteration 11... loss = 0.2489
# Iteration 12... loss = 0.2839
# Iteration 13... loss = 0.2572
# Iteration 14... loss = 0.2670
# Iteration 15... loss = 0.2406
# Iteration 16... loss = 0.2817
# Iteration 17... loss = 0.2618
# Iteration 18... loss = 0.2496
# Iteration 19... loss = 0.2569
# Iteration 20... loss = 0.2779
# Iteration 21... loss = 0.2547
# Iteration 22... loss = 0.2661
# Iteration 23... loss = 0.2896
# Iteration 24... loss = 0.2637
# Iteration 25... loss = 0.2311
# Iteration 26... loss = 0.2787
# Iteration 27... loss = 0.2844
# Iteration 28... loss = 0.2522
# Iteration 29... loss = 0.2553
# Iteration 30... loss = 0.2642
# Iteration 31... loss = 0.2434
# Iteration 32... loss = 0.2633
# Iteration 33... loss = 0.3064
# Iteration 34... loss = 0.2419
# Iteration 35... loss = 0.2097
# Iteration 36... loss = 0.2617
# Iteration 37... loss = 0.2470
# Iteration 38... loss = 0.2125
# Iteration 39... loss = 0.2715
# Iteration 40... loss = 0.2574
# Iteration 41... loss = 0.2139
# Iteration 42... loss = 0.2775
# Iteration 43... loss = 0.2441
# Iteration 44... loss = 0.2979
# Iteration 45... loss = 0.2371
# Iteration 46... loss = 0.1810
# Iteration 47... loss = 0.2006
# Iteration 48... loss = 0.1901
# Iteration 49... loss = 0.3598
# Iteration 50... loss = 0.3154
# Iteration 51... loss = 0.2285
# Iteration 52... loss = 0.1815
# Iteration 53... loss = 0.2534
# Iteration 54... loss = 0.2005
# Iteration 55... loss = 0.3678
# Iteration 56... loss = 0.2899
# Iteration 57... loss = 0.2754
# Iteration 58... loss = 0.1938
# Iteration 59... loss = 0.2638
# Iteration 60... loss = 0.2331
# Iteration 61... loss = 0.2436
# Iteration 62... loss = 0.2413
# Iteration 63... loss = 0.1948
# Iteration 64... loss = 0.2675
# Iteration 65... loss = 0.2287
# Iteration 66... loss = 0.2461
# Iteration 67... loss = 0.2354
# Iteration 68... loss = 0.1911
# Iteration 69... loss = 0.2765
# Iteration 70... loss = 0.2419
# Iteration 71... loss = 0.2603
# Iteration 72... loss = 0.2517
# Iteration 73... loss = 0.2128
# Iteration 74... loss = 0.2416
# Iteration 75... loss = 0.1997
# Iteration 76... loss = 0.3138
# Iteration 77... loss = 0.2627
# Iteration 78... loss = 0.2550
# Iteration 79... loss = 0.2003
# Iteration 80... loss = 0.1715
# Iteration 81... loss = 0.1727
# Iteration 82... loss = 0.1835
# Iteration 83... loss = 0.3010
# Iteration 84... loss = 0.2585
# Iteration 85... loss = 0.2797
# Iteration 86... loss = 0.2074
# Iteration 87... loss = 0.1538
# Iteration 88... loss = 0.2715
# Iteration 89... loss = 0.2464
# Iteration 90... loss = 0.2570
# Iteration 91... loss = 0.2212
# Iteration 92... loss = 0.1761
# Iteration 93... loss = 0.2497
# Iteration 94... loss = 0.2238
# Iteration 95... loss = 0.2238
# Iteration 96... loss = 0.2211
# Iteration 97... loss = 0.1797
# Iteration 98... loss = 0.2407
# Iteration 99... loss = 0.2188
# Iteration 100... loss = 0.2155
# Iteration 101... loss = 0.1970
# Iteration 102... loss = 0.1599
# Iteration 103... loss = 0.3098
# Iteration 104... loss = 0.2635
# Iteration 105... loss = 0.2647
# Iteration 106... loss = 0.1875
# Iteration 107... loss = 0.1528
# Iteration 108... loss = 0.1467
# Iteration 109... loss = 0.2264
# Iteration 110... loss = 0.2125
# Iteration 111... loss = 0.2122
# Iteration 112... loss = 0.1861
# Iteration 113... loss = 0.2161
# Iteration 114... loss = 0.2201
# Iteration 115... loss = 0.2078
# Iteration 116... loss = 0.1868
# Iteration 117... loss = 0.1491
# Iteration 118... loss = 0.2863
# Iteration 119... loss = 0.2565
# Iteration 120... loss = 0.2541
# Iteration 121... loss = 0.1937
# Iteration 122... loss = 0.1582
# Iteration 123... loss = 0.2993
# Iteration 124... loss = 0.2518
# Iteration 125... loss = 0.2475
# Iteration 126... loss = 0.1817
# Iteration 127... loss = 0.1449
# Iteration 128... loss = 0.1720
# Iteration 129... loss = 0.1682
# Iteration 130... loss = 0.2163
# Iteration 131... loss = 0.2117
# Iteration 132... loss = 0.2230
# Iteration 133... loss = 0.1877
# Iteration 134... loss = 0.1337
# Iteration 135... loss = 0.2446
# Iteration 136... loss = 0.2366
# Iteration 137... loss = 0.2280
# Iteration 138... loss = 0.2276
# Iteration 139... loss = 0.1936
# Iteration 140... loss = 0.2049
# Iteration 141... loss = 0.1740
# Iteration 142... loss = 0.3042
# Iteration 143... loss = 0.2462
# Iteration 144... loss = 0.2253
# Iteration 145... loss = 0.1733
# Iteration 146... loss = 0.1457
# Iteration 147... loss = 0.2022
# Iteration 148... loss = 0.1949
# Iteration 149... loss = 0.2007
# Iteration 150... loss = 0.1667
# Iteration 151... loss = 0.2479
# Iteration 152... loss = 0.2297
# Iteration 153... loss = 0.2189
# Iteration 154... loss = 0.2204
# Iteration 155... loss = 0.1867
# Iteration 156... loss = 0.1944
# Iteration 157... loss = 0.1700
# Iteration 158... loss = 0.2924
# Iteration 159... loss = 0.2392
# Iteration 160... loss = 0.2150
# Iteration 161... loss = 0.1772
# Iteration 162... loss = 0.1490
# Iteration 163... loss = 0.2384
# Iteration 164... loss = 0.2219
# Iteration 165... loss = 0.2185
# Iteration 166... loss = 0.1892
# Iteration 167... loss = 0.1503
# Iteration 168... loss = 0.2485
# Iteration 169... loss = 0.2224
# Iteration 170... loss = 0.2131
# Iteration 171... loss = 0.1953
# Iteration 172... loss = 0.1563
# Iteration 173... loss = 0.2091
# Iteration 174... loss = 0.1999
# Iteration 175... loss = 0.1839
# Iteration 176... loss = 0.1566
# Iteration 177... loss = 0.1600
# Iteration 178... loss = 0.1746
# Iteration 179... loss = 0.2329
# Iteration 180... loss = 0.2079
# Iteration 181... loss = 0.1851
# Iteration 182... loss = 0.1733
# Iteration 183... loss = 0.1428
# Iteration 184... loss = 0.2587
# Iteration 185... loss = 0.2346
# Iteration 186... loss = 0.2140
# Iteration 187... loss = 0.1940
# Iteration 188... loss = 0.1574
# Iteration 189... loss = 0.1943
# Iteration 190... loss = 0.1897
# Iteration 191... loss = 0.1816
# Iteration 192... loss = 0.1644
# Iteration 193... loss = 0.2682
# Iteration 194... loss = 0.2268
# Iteration 195... loss = 0.1976
# Iteration 196... loss = 0.1815
# Iteration 197... loss = 0.1504
# Iteration 198... loss = 0.2018
# Iteration 199... loss = 0.1965
# Iteration 200... loss = 0.1839
# Iteration 201... loss = 0.1540
# Iteration 202... loss = 0.1357
# Iteration 203... loss = 0.1506
# Iteration 204... loss = 0.2696
# Iteration 205... loss = 0.2262
# Iteration 206... loss = 0.1967
# Iteration 207... loss = 0.1862
# Iteration 208... loss = 0.1542
# Iteration 209... loss = 0.1823
# Iteration 210... loss = 0.1819
# Iteration 211... loss = 0.1795
# Iteration 212... loss = 0.1634
# Iteration 213... loss = 0.2502
# Iteration 214... loss = 0.2158
# Iteration 215... loss = 0.1854
# Iteration 216... loss = 0.1780
# Iteration 217... loss = 0.1475
# Iteration 218... loss = 0.2052
# Iteration 219... loss = 0.1983
# Iteration 220... loss = 0.1798
# Iteration 221... loss = 0.1516
# Iteration 222... loss = 0.1142
# Iteration 223... loss = 0.1112
# Iteration 224... loss = 0.1299
# Iteration 225... loss = 0.1478
# Iteration 226... loss = 0.2650
# Iteration 227... loss = 0.2254
# Iteration 228... loss = 0.1916
# Iteration 229... loss = 0.1878
# Iteration 230... loss = 0.1571
# Iteration 231... loss = 0.1730
# Iteration 232... loss = 0.1723
# Iteration 233... loss = 0.1898
# Iteration 234... loss = 0.1760
# Iteration 235... loss = 0.1700
# Iteration 236... loss = 0.1597
# Iteration 237... loss = 0.2251
# Iteration 238... loss = 0.2032
# Iteration 239... loss = 0.1663
# Iteration 240... loss = 0.1561
# Iteration 241... loss = 0.1292
# Iteration 242... loss = 0.2149
# Iteration 243... loss = 0.2083
# Iteration 244... loss = 0.1746
# Iteration 245... loss = 0.1590
# Iteration 246... loss = 0.1281
# Iteration 247... loss = 0.2149
# Iteration 248... loss = 0.2060
# Iteration 249... loss = 0.1738
# Iteration 250... loss = 0.1562
# Iteration 251... loss = 0.1261
# Iteration 252... loss = 0.2116
# Iteration 253... loss = 0.2029
# Iteration 254... loss = 0.1712
# Iteration 255... loss = 0.1490
# Iteration 256... loss = 0.1193
# Iteration 257... loss = 0.2036
# Iteration 258... loss = 0.1999
# Iteration 259... loss = 0.1668
# Iteration 260... loss = 0.1407
# Iteration 261... loss = 0.1088
# Iteration 262... loss = 0.1500
# Iteration 263... loss = 0.1612
# Iteration 264... loss = 0.1717
# Iteration 265... loss = 0.1685
# Iteration 266... loss = 0.1933
# Iteration 267... loss = 0.1797
# Iteration 268... loss = 0.1531
# Iteration 269... loss = 0.1361
# Iteration 270... loss = 0.2332
# Iteration 271... loss = 0.2093
# Iteration 272... loss = 0.1678
# Iteration 273... loss = 0.1703
# Iteration 274... loss = 0.1445
# Iteration 275... loss = 0.1834
# Iteration 276... loss = 0.1805
# Iteration 277... loss = 0.1559
# Iteration 278... loss = 0.1327
# Iteration 279... loss = 0.2074
# Iteration 280... loss = 0.1967
# Iteration 281... loss = 0.1552
# Iteration 282... loss = 0.1348
# Iteration 283... loss = 0.1070
# Iteration 284... loss = 0.1475
# Iteration 285... loss = 0.1595
# Iteration 286... loss = 0.1645
# Iteration 287... loss = 0.1651
# Iteration 288... loss = 0.1815
# Iteration 289... loss = 0.1707
# Iteration 290... loss = 0.1550
# Iteration 291... loss = 0.1458
# Iteration 292... loss = 0.2209
# Iteration 293... loss = 0.1992
# Iteration 294... loss = 0.1523
# Iteration 295... loss = 0.1445
# Iteration 296... loss = 0.1227
# Iteration 297... loss = 0.2034
# Iteration 298... loss = 0.1974
# Iteration 299... loss = 0.1553
# Iteration 300... loss = 0.1332

# %%
bio_f_score(y_test, y_p)
# Out:
# 0.6017302146747837

# %%
y_test
# Out:
# array(['O', 'B', 'I', ..., 'I', 'O', 'O'], dtype='<U1')

# %%
y_train
# Out:
# array(['O', 'O', 'B', ..., 'B', 'O', 'O'], dtype='<U1')
